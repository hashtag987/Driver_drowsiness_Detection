# %%
# !pip install torch==1.8.2+cpu torchvision==0.9.2+cpu torchaudio===0.8.2 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Collecting torch==1.8.2+cpu
#   Downloading https://download.pytorch.org/whl/lts/1.8/cpu/torch-1.8.2%2Bcpu-cp37-cp37m-win_amd64.whl (191.8 MB)
# Collecting torchvision==0.9.2+cpu
#   Downloading https://download.pytorch.org/whl/lts/1.8/cpu/torchvision-0.9.2%2Bcpu-cp37-cp37m-win_amd64.whl (847 kB)
# Collecting torchaudio===0.8.2
#   Downloading https://download.pytorch.org/whl/lts/1.8/torchaudio-0.8.2-cp37-none-win_amd64.whl (109 kB)
# Requirement already satisfied: typing-extensions in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from torch==1.8.2+cpu) (4.0.1)
# Collecting numpy
#   Downloading numpy-1.21.5-cp37-cp37m-win_amd64.whl (14.0 MB)
# Collecting pillow>=4.1.1
#   Downloading Pillow-8.4.0-cp37-cp37m-win_amd64.whl (3.2 MB)
# Installing collected packages: numpy, torch, pillow, torchvision, torchaudio
# Successfully installed numpy-1.21.5 pillow-8.4.0 torch-1.8.2+cpu torchaudio-0.8.2 torchvision-0.9.2+cpu
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\arun\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.5.1-cp37-cp37m-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from -r requirements.txt (line 5)) (1.21.5)
# Collecting opencv-python>=4.1.2
#   Downloading opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from -r requirements.txt (line 7)) (8.4.0)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
# Collecting requests>=2.23.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.7.3-cp37-cp37m-win_amd64.whl (34.1 MB)
# Requirement already satisfied: torch>=1.7.0 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from -r requirements.txt (line 11)) (1.8.2+cpu)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from -r requirements.txt (line 12)) (0.9.2+cpu)
# Collecting tqdm>=4.41.0
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Collecting pandas>=1.1.4
#   Downloading pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting thop
#   Downloading thop-0.0.31.post2005241907-py3-none-any.whl (8.7 kB)
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp37-cp37m-win_amd64.whl (51 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.5-py3-none-any.whl (890 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.6-py3-none-any.whl (97 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.9-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Requirement already satisfied: typing-extensions in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (4.0.1)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.4)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (47.1.0)
# Collecting wheel>=0.26
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.19.1-cp37-cp37m-win_amd64.whl (896 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.43.0-cp37-cp37m-win_amd64.whl (3.3 MB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: six>=1.5 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.16.0)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.10.0)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\arun\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.7.0)
# Installing collected packages: pyparsing, packaging, kiwisolver, fonttools, cycler, matplotlib, opencv-python, PyYAML, charset-normalizer, idna, urllib3, certifi, requests, scipy, tqdm, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, absl-py, wheel, werkzeug, protobuf, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-plugin-wit, markdown, grpcio, tensorboard-data-server, tensorboard, pytz, pandas, seaborn, thop
# Successfully installed PyYAML-6.0 absl-py-1.0.0 cachetools-4.2.4 certifi-2021.10.8 charset-normalizer-2.0.9 cycler-0.11.0 fonttools-4.28.5 google-auth-2.3.3 google-auth-oauthlib-0.4.6 grpcio-1.43.0 idna-3.3 kiwisolver-1.3.2 markdown-3.3.6 matplotlib-3.5.1 oauthlib-3.1.1 opencv-python-4.5.5.62 packaging-21.3 pandas-1.3.5 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.6 pytz-2021.3 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.8 scipy-1.7.3 seaborn-0.11.2 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 thop-0.0.31.post2005241907 tqdm-4.62.3 urllib3-1.26.7 werkzeug-2.0.2 wheel-0.37.1
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\arun\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Arun/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-1-1 torch 1.8.2+cpu CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img = 'https://images.theconversation.com/files/135193/original/image-20160823-30257-1dos8k6.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=926&fit=clip.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 610x926 23 cars, 7 trucks
# Speed: 1851.1ms pre-process, 235.4ms inference, 5.4ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
IMAGES_PATH1 = os.path.join('data', 'images2') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
from PIL import Image

# %%
#cap = cv2.VideoCapture(0)
dir1=r'C:\Users\Admin\Downloads\archive_1\dataset_new\train\no_yawn'
dir2=r'C:\Users\Admin\Downloads\archive_1\dataset_new\train\yawn'

# Loop through labels

    
    # Loop through image range
for file in os.listdir(dir1):
    if file.endswith(".jpg") or file.endswith(".png"):
        imgname = os.path.join(IMAGES_PATH1, 'awake'+'.'+str(uuid.uuid1())+'.jpg')
        image = np.array(Image.open(dir1+'/'+file))
        # Writes out image to file 
        cv2.imwrite(imgname, image)
        
        # Render to the screen
        cv2.imshow('Image Collection1', image)      
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    else:
        continue

for file in os.listdir(dir2):
    if file.endswith(".jpg") or file.endswith(".png"):
        imgname = os.path.join(IMAGES_PATH1, 'drowsy'+'.'+str(uuid.uuid1())+'.jpg')
        image = np.array(Image.open(dir2+'/'+file))
        # Writes out image to file 
        cv2.imwrite(imgname, image)
        
        # Render to the screen
        cv2.imshow('Image Collection1', image)      
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    else:
        continue
        
        
cap.release()
cv2.destroyAllWindows()

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 400 --data dataset.yaml --weights yolov5s.pt --workers 2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp17/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Arun/.cache\torch\hub\master.zip
# YOLOv5  2022-4-21 torch 1.8.2+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.7a37b514-3eda-11ec-bf97-d6421b542b49.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 46.4ms pre-process, 225.4ms inference, 16.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
